# %% [markdown]
# # Data
#
# ## data.TensorDataset
#
# `data.TensorDataset` 用于将多个tensor组合为数据集，**它接收任意个tensor作为参数**，但是要求这些tensor必须具有**相同的个数**（第一维度）。它会返回一个数据集，按照索引进行一一对应。

# %% [markdown]
# 导入一些需要的库。

# %%
import numpy as np
import torch
from torch.utils import data

# %% [markdown]
# 生成人造数据集。

# %%
def synthetic_data(w, b, m, n):
    """
    生成 Y=wX+b+noise 
    
    :param w: weight vector 
    :param b: bias scalar
    :param m: number of samples
    :param n: number of features
    :return: Y, labels value vector
    """
    # 生成一个期望值为0，方差为1，m*n的input features
    X = torch.normal(0, 1, (m, n))
    Y = X @ w.reshape(n, 1) + b
    
    # 噪声
    Y += torch.normal(0, 0.1, (m, 1))
    
    return X, Y.reshape(-1, 1)

w = torch.tensor([2, -3.4])
b = 4.2

features, labels = synthetic_data(w, b, 200, len(w))

# %% [markdown]
# 用特征features和标签labels生成dataset。

# %%
dataset = data.TensorDataset(features, labels)

for pair in dataset:
    print(pair)
# Out:
# (tensor([1.4950, 0.0587]), tensor([7.2415]))
# (tensor([ 0.2207, -1.0449]), tensor([8.2712]))
# (tensor([-0.2932,  1.4716]), tensor([-1.3809]))
# (tensor([-0.8460,  0.2562]), tensor([1.7191]))
# (tensor([ 0.3670, -1.5124]), tensor([10.0870]))
# (tensor([ 0.9160, -0.1174]), tensor([6.4876]))
# (tensor([-0.1704,  0.0618]), tensor([3.4861]))
# (tensor([0.3976, 1.0506]), tensor([1.4095]))
# (tensor([0.3924, 0.7528]), tensor([2.4889]))
# (tensor([ 0.0940, -1.3543]), tensor([8.9968]))
# (tensor([ 0.4798, -0.4883]), tensor([6.7201]))
# (tensor([0.9718, 1.1525]), tensor([2.2297]))
# (tensor([-0.5423,  0.3668]), tensor([1.9711]))
# (tensor([-1.3049,  1.7295]), tensor([-4.2141]))
# (tensor([-2.1158, -1.4262]), tensor([4.7655]))
# (tensor([-0.4838, -0.9356]), tensor([6.3588]))
# (tensor([-0.9606,  0.9473]), tensor([-1.2523]))
# (tensor([ 0.4634, -0.7921]), tensor([7.7563]))
# (tensor([ 0.2095, -0.5693]), tensor([6.5598]))
# (tensor([-0.1995,  1.1571]), tensor([-0.3136]))
# (tensor([-0.9703, -0.3003]), tensor([3.3520]))
# (tensor([-0.7258,  2.4163]), tensor([-5.4573]))
# (tensor([ 0.8105, -0.2171]), tensor([6.4761]))
# (tensor([ 0.9500, -1.4250]), tensor([10.9201]))
# (tensor([ 0.2124, -0.4706]), tensor([6.1456]))
# (tensor([ 1.8791, -1.2105]), tensor([12.0181]))
# (tensor([ 0.5614, -0.1376]), tensor([5.7679]))
# (tensor([-0.0542,  0.9192]), tensor([1.0736]))
# (tensor([-0.1424,  0.0265]), tensor([3.6808]))
# (tensor([ 0.8443, -0.2460]), tensor([6.6968]))
# (tensor([-0.1046,  0.7988]), tensor([1.3770]))
# (tensor([ 0.1882, -0.5324]), tensor([6.3116]))
# (tensor([-2.7914, -1.8142]), tensor([4.7821]))
# (tensor([0.8078, 0.4124]), tensor([4.5469]))
# (tensor([-0.5888,  0.8111]), tensor([0.0075]))
# (tensor([0.5071, 1.5782]), tensor([-0.1214]))
# (tensor([0.4102, 0.0596]), tensor([4.8255]))
# (tensor([-0.6908,  1.3041]), tensor([-1.6512]))
# (tensor([ 0.7336, -0.4600]), tensor([7.3649]))
# (tensor([0.3510, 0.3942]), tensor([3.4991]))
# (tensor([-0.7532, -0.2305]), tensor([3.5744]))
# (tensor([0.3670, 0.8151]), tensor([2.2568]))
# (tensor([ 0.3839, -0.4302]), tensor([6.5795]))
# (tensor([-0.5887,  1.1534]), tensor([-1.0172]))
# (tensor([0.1607, 0.2184]), tensor([3.8650]))
# (tensor([1.4386, 1.1101]), tensor([3.1555]))
# (tensor([-1.4926,  1.7284]), tensor([-4.7389]))
# (tensor([ 1.6690, -1.3172]), tensor([12.0815]))
# (tensor([2.1497, 0.3718]), tensor([7.2899]))
# (tensor([0.6044, 0.4654]), tensor([3.8224]))
# (tensor([-0.2011, -0.3515]), tensor([4.9751]))
# (tensor([-1.6725,  1.4422]), tensor([-4.1129]))
# (tensor([ 0.6915, -0.9887]), tensor([8.8506]))
# (tensor([-0.8366,  1.4043]), tensor([-2.2180]))
# (tensor([-1.2508, -0.0817]), tensor([2.0418]))
# (tensor([1.4320, 1.6887]), tensor([1.2799]))
# (tensor([0.1740, 0.9583]), tensor([1.3277]))
# (tensor([ 0.4809, -0.2179]), tensor([5.9207]))
# (tensor([-0.1498, -0.4730]), tensor([5.4869]))
# (tensor([-1.1967, -0.4623]), tensor([3.2802]))
# (tensor([0.6196, 0.6529]), tensor([3.1222]))
# (tensor([ 0.3406, -1.0461]), tensor([8.3247]))
# (tensor([0.2696, 1.1193]), tensor([0.7712]))
# (tensor([ 1.3580, -0.0051]), tensor([7.0669]))
# (tensor([-0.4703, -0.8525]), tensor([6.1309]))
# (tensor([-1.9062, -0.9929]), tensor([3.9246]))
# (tensor([-0.1958, -0.7038]), tensor([6.2671]))
# (tensor([1.4811, 0.0779]), tensor([6.9602]))
# (tensor([-0.3694, -0.2711]), tensor([4.4053]))
# (tensor([0.6366, 0.7665]), tensor([2.8202]))
# (tensor([ 1.4867, -1.2163]), tensor([11.4581]))
# (tensor([-0.5155,  1.4496]), tensor([-1.9336]))
# (tensor([-0.5703,  0.7014]), tensor([0.7917]))
# (tensor([-0.8623, -1.6698]), tensor([8.2099]))
# (tensor([-0.5897, -1.0019]), tensor([6.5479]))
# (tensor([0.7039, 1.3069]), tensor([1.1740]))
# (tensor([-1.2721,  0.0214]), tensor([1.5329]))
# (tensor([ 0.7408, -2.0248]), tensor([12.4522]))
# (tensor([0.9880, 0.9487]), tensor([3.0290]))
# (tensor([ 0.2780, -0.7252]), tensor([7.2938]))
# (tensor([ 0.6410, -0.8607]), tensor([8.4386]))
# (tensor([-0.2401,  1.1554]), tensor([-0.4262]))
# (tensor([-0.1876, -0.0907]), tensor([3.9759]))
# (tensor([-0.7388, -0.1773]), tensor([3.3367]))
# (tensor([-0.5175, -1.3799]), tensor([7.8925]))
# (tensor([0.0913, 0.2908]), tensor([3.2071]))
# (tensor([ 0.7776, -1.1440]), tensor([9.6277]))
# (tensor([-0.1874, -0.9614]), tensor([7.0837]))
# (tensor([ 1.2234, -0.8638]), tensor([9.7846]))
# (tensor([2.2697, 0.4756]), tensor([7.0702]))
# (tensor([-0.4175,  0.8103]), tensor([0.7449]))
# (tensor([1.2341, 0.3414]), tensor([5.7163]))
# (tensor([1.7744, 0.4460]), tensor([6.1748]))
# (tensor([ 0.4657, -1.3734]), tensor([9.8752]))
# (tensor([ 0.3004, -1.8371]), tensor([11.1020]))
# (tensor([-1.5098,  0.0925]), tensor([0.8517]))
# (tensor([-0.4866, -0.2171]), tensor([4.1116]))
# (tensor([-0.2874,  0.6805]), tensor([1.1808]))
# (tensor([ 0.3528, -0.1670]), tensor([5.4033]))
# (tensor([-0.5714, -1.3177]), tensor([7.5017]))
# (tensor([ 1.5332, -0.5152]), tensor([8.9434]))
# (tensor([ 1.2737, -0.5263]), tensor([8.4977]))
# (tensor([ 0.9704, -1.2132]), tensor([10.0795]))
# (tensor([-1.5946, -1.4607]), tensor([6.0955]))
# (tensor([-0.8716,  1.0865]), tensor([-1.3417]))
# (tensor([0.1852, 0.7636]), tensor([1.9411]))
# (tensor([ 0.8387, -2.5201]), tensor([14.3934]))
# (tensor([-0.2757,  1.1764]), tensor([-0.2962]))
# (tensor([-0.2656,  0.2463]), tensor([2.9248]))
# (tensor([-0.1784, -1.9109]), tensor([10.3557]))
# (tensor([-0.0947,  0.2490]), tensor([3.1726]))
# (tensor([-0.0628,  0.0152]), tensor([4.1439]))
# (tensor([0.5934, 0.9982]), tensor([1.8735]))
# (tensor([0.3858, 0.7598]), tensor([2.5009]))
# (tensor([-0.3412, -0.0862]), tensor([3.9373]))
# (tensor([-0.1651, -1.3528]), tensor([8.4420]))
# (tensor([-0.8370, -1.6238]), tensor([8.0141]))
# (tensor([0.1743, 0.4083]), tensor([3.0619]))
# (tensor([-0.8165,  0.6344]), tensor([0.3396]))
# (tensor([0.8524, 1.1275]), tensor([1.9961]))
# (tensor([ 0.8995, -2.9396]), tensor([15.8924]))
# (tensor([ 1.2825, -0.9060]), tensor([9.6842]))
# (tensor([ 0.6234, -2.0083]), tensor([12.2145]))
# (tensor([-0.5383, -1.7197]), tensor([8.8188]))
# (tensor([ 0.4479, -1.4177]), tensor([9.8996]))
# (tensor([0.0087, 0.3940]), tensor([2.8706]))
# (tensor([-0.1761, -1.3911]), tensor([8.4989]))
# (tensor([-1.0859, -1.5424]), tensor([7.2734]))
# (tensor([-0.9283, -0.5951]), tensor([4.3069]))
# (tensor([-0.6969,  0.7747]), tensor([0.3154]))
# (tensor([-0.0037, -0.7065]), tensor([6.5482]))
# (tensor([ 1.3843, -0.5777]), tensor([8.7768]))
# (tensor([-0.2419,  0.0664]), tensor([3.4465]))
# (tensor([-1.7753,  0.3829]), tensor([-0.7757]))
# (tensor([-1.1240,  0.7222]), tensor([-0.6300]))
# (tensor([-0.2187, -0.3880]), tensor([5.0355]))
# (tensor([-0.8890,  0.3094]), tensor([1.5102]))
# (tensor([-1.7308, -0.3636]), tensor([1.9882]))
# (tensor([1.3558, 0.8292]), tensor([3.8128]))
# (tensor([ 0.6658, -1.5273]), tensor([10.8047]))
# (tensor([-0.0461,  0.5006]), tensor([2.3948]))
# (tensor([-0.7308, -0.9183]), tensor([5.7803]))
# (tensor([ 1.4888, -0.7664]), tensor([9.5599]))
# (tensor([-0.2102, -0.0858]), tensor([3.9762]))
# (tensor([ 0.1122, -1.1782]), tensor([8.3306]))
# (tensor([-0.6277, -0.2751]), tensor([3.7845]))
# (tensor([-0.3635, -1.6295]), tensor([8.9960]))
# (tensor([-2.3451, -1.3059]), tensor([3.9359]))
# (tensor([-0.0551,  1.8919]), tensor([-2.2782]))
# (tensor([ 0.0201, -1.2595]), tensor([8.6127]))
# (tensor([ 1.4773, -0.8066]), tensor([9.8626]))
# (tensor([-1.2191, -0.3196]), tensor([2.6654]))
# (tensor([-1.1564,  0.7636]), tensor([-0.6494]))
# (tensor([-1.3306,  1.7392]), tensor([-4.4986]))
# (tensor([-1.0749, -0.5412]), tensor([3.7498]))
# (tensor([2.2337, 1.1610]), tensor([4.6844]))
# (tensor([0.5916, 0.5946]), tensor([3.4779]))
# (tensor([0.9565, 0.0851]), tensor([5.6765]))
# (tensor([-0.2351, -0.0999]), tensor([3.9393]))
# (tensor([-0.8821,  0.0080]), tensor([2.4176]))
# (tensor([ 0.8317, -0.2761]), tensor([7.0665]))
# (tensor([-1.6395,  1.0591]), tensor([-2.5716]))
# (tensor([ 1.6635, -2.3234]), tensor([15.3741]))
# (tensor([ 0.4455, -0.2434]), tensor([6.0331]))
# (tensor([0.4141, 0.7711]), tensor([2.2219]))
# (tensor([-1.0188, -0.3094]), tensor([3.2843]))
# (tensor([ 1.0554, -0.5573]), tensor([8.1719]))
# (tensor([ 0.5926, -0.3433]), tensor([6.3189]))
# (tensor([ 0.2919, -0.0923]), tensor([4.9947]))
# (tensor([-1.6697, -0.2348]), tensor([1.6514]))
# (tensor([-1.0055, -1.0593]), tensor([5.8716]))
# (tensor([0.9940, 0.2303]), tensor([5.3536]))
# (tensor([0.8628, 1.0374]), tensor([2.5443]))
# (tensor([ 0.9293, -0.8555]), tensor([9.0079]))
# (tensor([-1.8213, -1.2552]), tensor([4.8093]))
# (tensor([-0.2359, -0.9874]), tensor([6.9757]))
# (tensor([-0.6917, -0.8684]), tensor([5.8059]))
# (tensor([-0.1442,  1.0079]), tensor([0.5616]))
# (tensor([-0.4885, -1.3645]), tensor([7.7844]))
# (tensor([-0.5274,  0.0243]), tensor([3.2115]))
# (tensor([ 0.2083, -0.1862]), tensor([5.2556]))
# (tensor([0.3498, 1.7341]), tensor([-0.9675]))
# (tensor([-1.5606, -1.1260]), tensor([4.9311]))
# (tensor([-0.5742, -0.4336]), tensor([4.3494]))
# (tensor([ 0.2614, -0.5844]), tensor([6.5658]))
# (tensor([ 1.3363, -0.4616]), tensor([8.2983]))
# (tensor([-0.0696,  0.5576]), tensor([2.3649]))
# (tensor([-0.3771,  0.4068]), tensor([2.0917]))
# (tensor([-0.5173,  0.4943]), tensor([1.5954]))
# (tensor([-0.8305, -0.4317]), tensor([4.0565]))
# (tensor([0.3136, 1.9516]), tensor([-1.8052]))
# (tensor([-0.5443, -1.0033]), tensor([6.6144]))
# (tensor([-1.1586,  0.0091]), tensor([1.9394]))
# (tensor([-0.4763, -0.4244]), tensor([4.6340]))
# (tensor([2.0254, 0.7906]), tensor([5.3953]))
# (tensor([ 0.6064, -1.2839]), tensor([9.9312]))
# (tensor([0.3084, 1.7196]), tensor([-1.1531]))
# (tensor([0.6744, 0.8812]), tensor([2.4880]))
# (tensor([-0.4938,  0.1663]), tensor([2.5277]))
# (tensor([0.0403, 0.2541]), tensor([3.6250]))

# %% [markdown]
# ## data.DataLoader
#
# `data.DataLoader` 负责批量加载数据，并且提供批量处理、数据打乱、多线程加载等功能，它可以高效地从数据集中抽取小批量的数据集。它接收一个Dataset对象，其余参数可以控制批量大小，数据打乱，多线程加载等功能。它返回一个迭代器 (Iterator) 形式的batch，可以用 `for`, `next` 得到batch中的元素。

# %% [markdown]
# 创建一个dataloader。
#
# - dataset: Dataset对象
# - batch_size: 批量大小
# - shuffle: 是否进行数据打乱
# - drop_last: 是否丢弃最后无法捆成一簇的数据
# - num_workers: 进程数

# %%
dataloader = data.DataLoader(dataset, batch_size=15, shuffle=True, drop_last=True, num_workers=3)

for batch in dataloader:
    print(batch)
# Out:
# [tensor([[ 1.3558,  0.8292],
#         [-0.2102, -0.0858],
#         [-0.1874, -0.9614],
#         [-0.3694, -0.2711],
#         [-1.0749, -0.5412],
#         [-0.0551,  1.8919],
#         [-0.8716,  1.0865],
#         [-0.1498, -0.4730],
#         [ 1.2825, -0.9060],
#         [ 0.7776, -1.1440],
#         [ 0.7336, -0.4600],
#         [ 0.0403,  0.2541],
#         [ 0.5916,  0.5946],
#         [ 0.5926, -0.3433],
#         [-0.2401,  1.1554]]), tensor([[ 3.8128],
#         [ 3.9762],
#         [ 7.0837],
#         [ 4.4053],
#         [ 3.7498],
#         [-2.2782],
#         [-1.3417],
#         [ 5.4869],
#         [ 9.6842],
#         [ 9.6277],
#         [ 7.3649],
#         [ 3.6250],
#         [ 3.4779],
#         [ 6.3189],
#         [-0.4262]])]
# [tensor([[ 0.1852,  0.7636],
#         [ 0.9565,  0.0851],
#         [ 0.6234, -2.0083],
#         [ 0.8078,  0.4124],
#         [-1.1240,  0.7222],
#         [-2.1158, -1.4262],
#         [ 1.2341,  0.3414],
#         [ 0.4141,  0.7711],
#         [ 0.6196,  0.6529],
#         [ 1.3843, -0.5777],
#         [ 0.3976,  1.0506],
#         [-0.5742, -0.4336],
#         [-0.5383, -1.7197],
#         [-1.0859, -1.5424],
#         [-1.8213, -1.2552]]), tensor([[ 1.9411],
#         [ 5.6765],
#         [12.2145],
#         [ 4.5469],
#         [-0.6300],
#         [ 4.7655],
#         [ 5.7163],
#         [ 2.2219],
#         [ 3.1222],
#         [ 8.7768],
#         [ 1.4095],
#         [ 4.3494],
#         [ 8.8188],
#         [ 7.2734],
#         [ 4.8093]])]
# [tensor([[-0.7258,  2.4163],
#         [ 0.3924,  0.7528],
#         [ 0.0913,  0.2908],
#         [ 0.6915, -0.9887],
#         [-0.4763, -0.4244],
#         [-0.8460,  0.2562],
#         [ 0.3136,  1.9516],
#         [-0.2932,  1.4716],
#         [ 0.8105, -0.2171],
#         [ 0.3084,  1.7196],
#         [ 0.6366,  0.7665],
#         [ 1.4320,  1.6887],
#         [-0.1784, -1.9109],
#         [-0.3635, -1.6295],
#         [-0.1651, -1.3528]]), tensor([[-5.4573],
#         [ 2.4889],
#         [ 3.2071],
#         [ 8.8506],
#         [ 4.6340],
#         [ 1.7191],
#         [-1.8052],
#         [-1.3809],
#         [ 6.4761],
#         [-1.1531],
#         [ 2.8202],
#         [ 1.2799],
#         [10.3557],
#         [ 8.9960],
#         [ 8.4420]])]
# [tensor([[ 0.1122, -1.1782],
#         [-2.7914, -1.8142],
#         [ 0.4798, -0.4883],
#         [ 1.6635, -2.3234],
#         [ 0.1607,  0.2184],
#         [-1.6725,  1.4422],
#         [-0.8821,  0.0080],
#         [-0.9606,  0.9473],
#         [-0.5274,  0.0243],
#         [ 0.1882, -0.5324],
#         [ 0.3498,  1.7341],
#         [-1.7308, -0.3636],
#         [ 1.4811,  0.0779],
#         [-0.2419,  0.0664],
#         [ 0.4657, -1.3734]]), tensor([[ 8.3306],
#         [ 4.7821],
#         [ 6.7201],
#         [15.3741],
#         [ 3.8650],
#         [-4.1129],
#         [ 2.4176],
#         [-1.2523],
#         [ 3.2115],
#         [ 6.3116],
#         [-0.9675],
#         [ 1.9882],
#         [ 6.9602],
#         [ 3.4465],
#         [ 9.8752]])]
# [tensor([[-1.2508, -0.0817],
#         [ 0.9880,  0.9487],
#         [-0.6917, -0.8684],
#         [ 0.2614, -0.5844],
#         [ 0.2919, -0.0923],
#         [-0.6277, -0.2751],
#         [-0.2359, -0.9874],
#         [-0.5714, -1.3177],
#         [-0.5443, -1.0033],
#         [ 1.4867, -1.2163],
#         [-1.1586,  0.0091],
#         [ 0.9704, -1.2132],
#         [ 0.6744,  0.8812],
#         [-0.2187, -0.3880],
#         [ 0.9160, -0.1174]]), tensor([[ 2.0418],
#         [ 3.0290],
#         [ 5.8059],
#         [ 6.5658],
#         [ 4.9947],
#         [ 3.7845],
#         [ 6.9757],
#         [ 7.5017],
#         [ 6.6144],
#         [11.4581],
#         [ 1.9394],
#         [10.0795],
#         [ 2.4880],
#         [ 5.0355],
#         [ 6.4876]])]
# [tensor([[ 1.7744,  0.4460],
#         [ 0.3858,  0.7598],
#         [-0.2011, -0.3515],
#         [-0.5175, -1.3799],
#         [ 0.8995, -2.9396],
#         [ 1.4386,  1.1101],
#         [-1.3306,  1.7392],
#         [-0.7388, -0.1773],
#         [ 0.4479, -1.4177],
#         [ 0.6658, -1.5273],
#         [ 0.4455, -0.2434],
#         [ 0.7408, -2.0248],
#         [-0.9703, -0.3003],
#         [-1.5098,  0.0925],
#         [ 1.5332, -0.5152]]), tensor([[ 6.1748],
#         [ 2.5009],
#         [ 4.9751],
#         [ 7.8925],
#         [15.8924],
#         [ 3.1555],
#         [-4.4986],
#         [ 3.3367],
#         [ 9.8996],
#         [10.8047],
#         [ 6.0331],
#         [12.4522],
#         [ 3.3520],
#         [ 0.8517],
#         [ 8.9434]])]
# [tensor([[ 0.3839, -0.4302],
#         [-1.1564,  0.7636],
#         [ 0.2696,  1.1193],
#         [-0.0947,  0.2490],
#         [ 0.3528, -0.1670],
#         [-0.1704,  0.0618],
#         [ 0.3510,  0.3942],
#         [ 1.6690, -1.3172],
#         [ 0.3004, -1.8371],
#         [-0.4175,  0.8103],
#         [ 0.5934,  0.9982],
#         [ 0.0940, -1.3543],
#         [ 0.5614, -0.1376],
#         [ 1.8791, -1.2105],
#         [-0.0628,  0.0152]]), tensor([[ 6.5795],
#         [-0.6494],
#         [ 0.7712],
#         [ 3.1726],
#         [ 5.4033],
#         [ 3.4861],
#         [ 3.4991],
#         [12.0815],
#         [11.1020],
#         [ 0.7449],
#         [ 1.8735],
#         [ 8.9968],
#         [ 5.7679],
#         [12.0181],
#         [ 4.1439]])]
# [tensor([[-0.5423,  0.3668],
#         [-0.1442,  1.0079],
#         [-0.7532, -0.2305],
#         [-0.5703,  0.7014],
#         [ 1.3580, -0.0051],
#         [-1.9062, -0.9929],
#         [ 1.4773, -0.8066],
#         [ 0.4809, -0.2179],
#         [-1.7753,  0.3829],
#         [ 0.8524,  1.1275],
#         [-1.2191, -0.3196],
#         [ 1.0554, -0.5573],
#         [ 0.0201, -1.2595],
#         [ 0.3670, -1.5124],
#         [ 0.1743,  0.4083]]), tensor([[ 1.9711],
#         [ 0.5616],
#         [ 3.5744],
#         [ 0.7917],
#         [ 7.0669],
#         [ 3.9246],
#         [ 9.8626],
#         [ 5.9207],
#         [-0.7757],
#         [ 1.9961],
#         [ 2.6654],
#         [ 8.1719],
#         [ 8.6127],
#         [10.0870],
#         [ 3.0619]])]
# [tensor([[-0.4838, -0.9356],
#         [ 2.2697,  0.4756],
#         [-0.8305, -0.4317],
#         [-0.6969,  0.7747],
#         [ 0.9718,  1.1525],
#         [-0.5887,  1.1534],
#         [-0.5897, -1.0019],
#         [-1.2721,  0.0214],
#         [ 0.0087,  0.3940],
#         [ 0.1740,  0.9583],
#         [ 0.3670,  0.8151],
#         [-1.1967, -0.4623],
#         [ 2.2337,  1.1610],
#         [-0.4866, -0.2171],
#         [-0.5888,  0.8111]]), tensor([[ 6.3588],
#         [ 7.0702],
#         [ 4.0565],
#         [ 0.3154],
#         [ 2.2297],
#         [-1.0172],
#         [ 6.5479],
#         [ 1.5329],
#         [ 2.8706],
#         [ 1.3277],
#         [ 2.2568],
#         [ 3.2802],
#         [ 4.6844],
#         [ 4.1116],
#         [ 0.0075]])]
# [tensor([[-0.4938,  0.1663],
#         [-0.1761, -1.3911],
#         [ 0.8443, -0.2460],
#         [-0.0696,  0.5576],
#         [-0.0037, -0.7065],
#         [-0.1876, -0.0907],
#         [-2.3451, -1.3059],
#         [ 0.2207, -1.0449],
#         [ 0.4102,  0.0596],
#         [ 1.4888, -0.7664],
#         [-0.5173,  0.4943],
#         [ 1.2234, -0.8638],
#         [-0.0542,  0.9192],
#         [-0.3771,  0.4068],
#         [-1.6395,  1.0591]]), tensor([[ 2.5277],
#         [ 8.4989],
#         [ 6.6968],
#         [ 2.3649],
#         [ 6.5482],
#         [ 3.9759],
#         [ 3.9359],
#         [ 8.2712],
#         [ 4.8255],
#         [ 9.5599],
#         [ 1.5954],
#         [ 9.7846],
#         [ 1.0736],
#         [ 2.0917],
#         [-2.5716]])]
# [tensor([[ 0.3406, -1.0461],
#         [ 0.9500, -1.4250],
#         [-1.3049,  1.7295],
#         [-0.8890,  0.3094],
#         [-0.1424,  0.0265],
#         [-0.1995,  1.1571],
#         [ 0.2124, -0.4706],
#         [-0.2351, -0.0999],
#         [-1.4926,  1.7284],
#         [ 2.1497,  0.3718],
#         [ 0.8317, -0.2761],
#         [ 0.6044,  0.4654],
#         [-0.1046,  0.7988],
#         [-0.8623, -1.6698],
#         [ 0.5071,  1.5782]]), tensor([[ 8.3247],
#         [10.9201],
#         [-4.2141],
#         [ 1.5102],
#         [ 3.6808],
#         [-0.3136],
#         [ 6.1456],
#         [ 3.9393],
#         [-4.7389],
#         [ 7.2899],
#         [ 7.0665],
#         [ 3.8224],
#         [ 1.3770],
#         [ 8.2099],
#         [-0.1214]])]
# [tensor([[-1.5946, -1.4607],
#         [ 0.4634, -0.7921],
#         [ 0.8387, -2.5201],
#         [ 0.2780, -0.7252],
#         [ 0.2083, -0.1862],
#         [-0.4703, -0.8525],
#         [ 0.9940,  0.2303],
#         [-1.5606, -1.1260],
#         [-1.6697, -0.2348],
#         [-0.5155,  1.4496],
#         [-1.0188, -0.3094],
#         [ 0.2095, -0.5693],
#         [-0.3412, -0.0862],
#         [-0.1958, -0.7038],
#         [ 0.7039,  1.3069]]), tensor([[ 6.0955],
#         [ 7.7563],
#         [14.3934],
#         [ 7.2938],
#         [ 5.2556],
#         [ 6.1309],
#         [ 5.3536],
#         [ 4.9311],
#         [ 1.6514],
#         [-1.9336],
#         [ 3.2843],
#         [ 6.5598],
#         [ 3.9373],
#         [ 6.2671],
#         [ 1.1740]])]
# [tensor([[-0.2656,  0.2463],
#         [-0.9283, -0.5951],
#         [-0.2874,  0.6805],
#         [ 0.8628,  1.0374],
#         [ 2.0254,  0.7906],
#         [-0.6908,  1.3041],
#         [ 0.6064, -1.2839],
#         [-0.2757,  1.1764],
#         [ 1.3363, -0.4616],
#         [-0.8165,  0.6344],
#         [ 1.2737, -0.5263],
#         [ 0.6410, -0.8607],
#         [ 1.4950,  0.0587],
#         [-0.4885, -1.3645],
#         [-0.0461,  0.5006]]), tensor([[ 2.9248],
#         [ 4.3069],
#         [ 1.1808],
#         [ 2.5443],
#         [ 5.3953],
#         [-1.6512],
#         [ 9.9312],
#         [-0.2962],
#         [ 8.2983],
#         [ 0.3396],
#         [ 8.4977],
#         [ 8.4386],
#         [ 7.2415],
#         [ 7.7844],
#         [ 2.3948]])]
